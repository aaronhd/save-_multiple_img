# %%
import numpy as np
import pandas as pd
import plotly.plotly as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import seaborn as sns

# %%
c = np.load("a.npy")
print(c.shape)
f, ax = plt.subplots(figsize = (3.5, 3.5), dpi=100)# ax.invert_yaxis()
# Out:
# (304, 304)

# %%
# ax = sns.heatmap(c, cmap='jet',xticklabels=50, yticklabels=50)
ax = sns.heatmap(c, cmap='jet',xticklabels=False, yticklabels=False, cbar= False)

# sns.heatmap(c,cmap='jet')
# ax.invert_yaxis()
ax.xaxis.tick_top()

# %%
ax.figure.savefig("output.png")

print(type(ax))
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>
